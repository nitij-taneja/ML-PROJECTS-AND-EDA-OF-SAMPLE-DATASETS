# %%
# !pip install autoviz
# Out:
# ...
#      ---------------------------------------- 67.0/67.0 kB ? eta 0:00:00
# ...
#   Using cached xgboost-1.7.6-py3-none-win_amd64.whl (70.9 MB)
# ...
#      ---------------------------------------- 3.1/3.1 MB 14.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.3/4.3 MB 11.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 636.8/636.8 kB 8.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 361.8/361.8 kB 22.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import pandas as pd
data =pd.read_csv('application_record.csv')
data
# Out:
#           ID    CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804       M           Y              Y              0
# 1       5008805       M           Y              Y              0
# 2       5008806       M           Y              Y              0
# 3       5008808       F           N              Y              0
# 4       5008809       F           N              Y              0
# ...         ...         ...          ...             ...           ...
# 438552  6840104       M           N              Y              0
# 438553  6840222       F           N              N              0
# 438554  6841878       F           N              N              0
# 438555  6842765       F           N              Y              0
# 438556  6842885       F           N              Y              0
#
#         AMT_INCOME_TOTAL    NAME_INCOME_TYPE        NAME_EDUCATION_TYPE        \
# 0           427500.0                   Working               Higher education
# ...

# %%
data.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
data.shape
# Out:
# (304354, 18)

# %%
data.duplicated()
# Out:
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
#           ...
# 438541    False
# 438548    False
# 438553    False
# 438554    False
# 438556    False
# Length: 304354, dtype: bool

# %%
data.to_csv('credit_data.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV =AutoViz_Class()

import matplotlib.pyplot as plt

# %matplotlib inline

df=AV.AutoViz('credit_data.csv')
# Out:
#     max_rows_analyzed is smaller than dataset shape 304354...
#         randomly sampled 150000 rows from read CSV file
# Shape of your Data Set loaded: (150000, 19)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     19 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 0', 'ID', 'FLAG_MOBIL']
# Since Number of Rows in data 150000 exceeds maximum, randomly sampling 150000 rows for EDA...
# To fix data quality issues automatically, import FixDQ from autoviz...
# <style type="text/css">
# ...

# %% [markdown]
# # OBSERVATIONS

# %% [markdown]
# 1) More than 60% applicants are female.
#
# 2) Around 40-45% applcants own a car.
#
# 3) Almost 70% applicants own realty.
#
# 4) Only around a quarter of applicants own a work phone.
#
# 5) Around 28% applcants own a phone.
#
# 6) 10% applicants have submiited their email it seem it is not necessary at all for credit approval.
#
# 7) Every one having a mobile so we can say it doesn't create any impact over the results.
#
# 8) More than 60% applicants are not having a child while a quarter of it are having 1 child and around 12% having 2 childen and very few are having more than that.
#
# 9) More than 60% applicants income type is working.
#
# 10) Almost 70% applicants went for seconday special eduaction and around 27% got a higher degree.
#
# 11) Around 70% applicants are married.
#
# 12) Almost 90% applicanst own house or an apartment for themselves.
#
# 13) A quarter of applicants are laborers remaing are distributed among differnet occupations.
#
# 14) Count of child and count of family membere are highly correlated field.
