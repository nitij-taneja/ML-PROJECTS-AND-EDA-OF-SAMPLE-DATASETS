# %%
# !pip install klib

# %%
import pandas as pd
df = pd.read_csv('Spotify_Song_Attributes.csv')

# %%
df
# Out:
#                                               track_name  \
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# 5                                          (L)only Child
# ...                                                  ...
# 10074                                            Younger
# 10075                                 Younger with Time.
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                      artist_name  ms_played              genre  danceability  \
# 1      London Symphony Orchestra    1806234  british orchestra         0.475
# 2                           SyKo     145610         glitchcore         0.691
# ...

# %%
df.shape
# Out:
# (10080, 22)

# %%
df.isnull().sum()
# Out:
# trackName              0
# artistName             0
# msPlayed               0
# genre               1500
# danceability         550
# energy               550
# key                  550
# loudness             550
# mode                 550
# speechiness          550
# acousticness         550
# instrumentalness     550
# liveness             550
# valence              550
# tempo                550
# type                 550
# id                   550
# uri                  550
# track_href           550
# analysis_url         550
# duration_ms          550
# time_signature       550
# dtype: int64

# %%
df.isnull().sum()
# Out:
# track_name          0
# artist_name         0
# ms_played           0
# genre               0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df.shape
# Out:
# (8580, 22)

# %%
import klib

# %%
klib.missingval_plot(df)
# Out:
# No missing values found in the dataset.

# %%
df.describe()
# Out:
#           ms_played  danceability       energy          key     loudness  \
# count  8.580000e+03   8580.000000  8580.000000  8580.000000  8580.000000
# mean   1.535919e+06      0.601829     0.566844     5.246387    -8.577849
# std    5.558702e+06      0.158510     0.241653     3.574611     5.328715
# min    0.000000e+00      0.000000     0.001080     0.000000   -42.044000
# 25%    1.398700e+05      0.508000     0.407000     2.000000   -10.009000
# 50%    2.699110e+05      0.623000     0.592000     5.000000    -7.129000
# 75%    1.215632e+06      0.714000     0.753000     8.000000    -5.312000
# max    1.583671e+08      0.976000     0.999000    11.000000     3.010000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  8580.000000  8580.000000   8580.000000       8580.000000  8580.000000
# mean      0.616317     0.078321      0.357838          0.149342     0.174668
# std       0.486311     0.078535      0.332769          0.309771     0.130902
# ...

# %%
klib.cat_plot(df)
# Out:
# GridSpec(6, 8)

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# ...

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='time_signature', ylabel='Density'>

# %%
klib.clean_column_names(df)
# Out:
#                                               track_name  \
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# 5                                          (L)only Child
# ...                                                  ...
# 10074                                            Younger
# 10075                                 Younger with Time.
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                      artist_name  ms_played              genre  danceability  \
# 1      London Symphony Orchestra    1806234  british orchestra         0.475
# 2                           SyKo     145610         glitchcore         0.691
# ...

# %%
df.dtypes
# Out:
# track_name           object
# artist_name          object
# ms_played             int64
# genre                object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
df.loc[df['ms_played']==df['ms_played'].max()]
# Out:
#                 track_name artist_name  ms_played  genre  danceability  \
# 4194  Sparkle - movie ver.    RADWIMPS  158367130  j-pop         0.372
# 9234  Sparkle - movie ver.    RADWIMPS  158367130  j-pop         0.372
#
#       energy   key  loudness  mode  speechiness  ...  liveness  valence  \
# 4194   0.426  11.0    -8.421   1.0       0.0339  ...     0.109    0.287
# 9234   0.426  11.0    -8.421   1.0       0.0339  ...     0.109    0.287
#
#         tempo            type                      id  \
# 4194  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 9234  123.993  audio_features  3A4FRzgve9BjfKbvVXRIFO
#
#                                        uri  \
# 4194  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 9234  spotify:track:3A4FRzgve9BjfKbvVXRIFO
#
#                                              track_href  \
# 4194  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 9234  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
#
# ...

# %% [markdown]
# # Observations

# %% [markdown]
# 1) Alt Z and pop music genre are maximum available on spotify.
#
# 2) Blackbear records the highest number of songs on spotify.
#
# 3) Loudness of song impacts the listeners, they feel more energetic.
#
# 4) The more the song is valence(happy, cheerful) , the more it becomes energetic and itd danceability factor icreases.
#
# 5) The more acousticness and tempo available in song , it decreases the energy and loudness of song. \
#
# 6) Sparkle - movie ver is the most poular song on spotify with the highest ms played.
